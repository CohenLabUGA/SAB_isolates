# %% [markdown]
# Read in tables with significant DEGs and mapped annotations like GO or KEGG. Create vector of Kegg id's to match them to a descriptive name.

# %%
library('tidyr')
library('ggplot2')
library('stringr')
library('dplyr')
library("RCurl")
library('tibble')
library('KEGGREST')
library('RCurl')
#library('enrichplot')
#library('data.table')
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘RCurl’
#
#
# The following object is masked from ‘package:tidyr’:
#
#     complete

# %% [markdown]
# # Read in kegg annotations from eggnog
# ## make a list of all unique kegg_ko's from all annotations

# %%
get.eggnog <- function(org){
    dir2  <- paste("/work/nclab/lucy/SAB/Annotation/eggnog/", org, sep="")
    
    emap <- read.csv(file.path(dir2, paste(org,".emapper.annotations", sep="")),
                 sep = "\t",
                 comment.char = "#",
                 header = FALSE,
                 na.strings = "-")
    
    colnames(emap) <- c(
        'orfs', 'seed_ortholog', 'evalue', 'score', 'eggNOG_OGs', 'max_annot_lvl', 'COG_category', 'Description', 
        'Preferred_name', 'GOs', 'EC', 'ko_id', 'KEGG_Pathway', 'KEGG_Module', 'KEGG_Reaction', 
        'KEGG_rclass',  'BRITE', 'KEGG_TC', 'CAZy', 'BiGG_Reaction', 'PFAMs')
    
    emap[, c("orfs", "seed_ortholog", "EC","GOs","ko_id",'KEGG_Pathway', 'KEGG_Module', 'KEGG_Reaction', 
       'KEGG_rclass',  'BRITE', 'KEGG_TC', 'CAZy', 'BiGG_Reaction',"PFAMs")]
    }

emap4 <- get.eggnog('04')
emap8 <- get.eggnog('08')
emap6 <- get.eggnog('06')
emap13 <- get.eggnog('13')

# %%
length(na.omit(emap4$ko_id))
# Out:
# [1] 12264

# %% [markdown]
# Create df for each organism with annotation of choice, removing the rows with NA's

# %%
get.anno <- function(emap, anno){
    #extract query column and annotation of choice, ex: pfams
    vars <- c("orfs", anno)
    df <- select(emap, all_of(vars))
    df <- df %>% filter(is.na(df[,ncol(df)])==FALSE)
    }

pfam4 <- get.anno(emap4, "PFAMs")
pfam8 <- get.anno(emap8, "PFAMs")
pfam6 <- get.anno(emap6, "PFAMs")
pfam13 <- get.anno(emap13, "PFAMs")

ko4_ls <- get.anno(emap4,"ko_id")
ko8_ls <- get.anno(emap8,"ko_id")
ko6_ls <- get.anno(emap6,"ko_id")
ko13_ls <- get.anno(emap13,"ko_id")

go4 <- get.anno(emap4, "GOs")
go8 <- get.anno(emap8, "GOs")
go6 <- get.anno(emap6, "GOs")
go13 <- get.anno(emap13, "GOs")

paths4 <- get.anno(emap4, c('KEGG_Module', 'KEGG_Pathway','BRITE'))
paths8 <- get.anno(emap8, c('KEGG_Module', 'KEGG_Pathway','BRITE'))
paths6 <- get.anno(emap6, c('KEGG_Module', 'KEGG_Pathway','BRITE'))
paths13 <- get.anno(emap13, c('KEGG_Module', 'KEGG_Pathway','BRITE'))

# %%
print('# kos')
dim(ko4_ls)
dim(ko8_ls)
dim(ko6_ls)
dim(ko13_ls)
print('# pfams')
dim(pfam4)
dim(pfam8)
dim(pfam6)
dim(pfam13)
print('# gos')
dim(go4)
dim(go8)
dim(go6)
dim(go13)

# %% [markdown]
# ## Create a ko-to-orf mapping table
# #### Split columns with mulitple annotations and pivot into a long table with repeating orfs
# This will give us a 3 column table with columns 'orfs', 'ko_id', and 'ko_iteration'; which repeats orfs for rows from original table with multiple eggnog assignments. The ko_iteration increases from 1 to n for n eggnog assignmnet for a particular orf.

# %%
split_into_multiple <- function(column, pattern = ",", into_prefix){
    #adapted from post on stack overflow
    cols <- str_split_fixed(column, pattern, n = Inf)
  # Replace empty matrix indicies with NA's 
    cols[which(cols == "")] <- NA
  # turn matrix into a table with unique but arbitraty column names  
    cols <- as_tibble(cols, .name_repair = make.names)
  # where m = # columns in tibble 'cols'
    m <- dim(cols)[2]
  # assign column names as 'into_prefix_1', 'into_prefix_2', ..., 'into_prefix_m' 
    names(cols) <- paste(into_prefix, 1:m, sep = "_")
    print('# of values in matrix w/o NA:')
    print(sum(!is.na(cols)))
    return(cols)
}



clean_ko <- function(df, org){
  # split up ko_id's into multiple columns naming each column 
  # ko:_1 to ko:_n 
  # (remember at this point we have the same number of rows but 
  # far more columns)
    ko_iterations <- split_into_multiple(df$ko_id, ",", "ko:")
  # select the orfs column from original df and bind to to 
  # split columns 
    df = df %>% select(orfs) %>% bind_cols(ko_iterations)
  # now combine all ko:_n columns so all ko_id's 
  # become one column called ko_id and each column name, 
  # 'ko:_1'...'ko:_n' becomes one column called 'ko_iteration'. 
  # This tells us how many ko_id's were assigned to a particular orf
  # the column 'orfs' will repeat values for rows with > 1 ko_iteration
  # Drop the values from the matrix which were NA
    df_clean = pivot_longer(df, cols = !orfs, values_drop_na = T,
                            values_to = 'ko_id', names_to = 'ko_iteration')
  # finally, clean up the df a bit by removing the ko_id prefixes 'ko:'
  # we now have a 3 column table with orfs repeated in for each instance 
  # a ko_id was assigned to it by eggnog!
    df_clean$ko_id <- gsub('ko:', '', df_clean$ko_id)
  # the final df should have same number of rows as sum(!na(cols))
    print('# rows in final df:')
    print(nrow(df_clean))
    write.csv(df_clean, paste('../kegg_names/ko',org, '_ls.csv', sep=''), row.names=F)
    df_clean
    }

ko4 <- clean_ko(ko4_ls,'4')
ko6 <- clean_ko(ko6_ls,'6')
ko8 <- clean_ko(ko8_ls,'8')
ko13 <- clean_ko(ko13_ls,'13')
# Out:
# [1] "# of values in matrix w/o NA:"
# [1] 14281
# [1] "# rows in final df:"
# [1] 14281
# [1] "# of values in matrix w/o NA:"
# [1] 35251
# [1] "# rows in final df:"
# [1] 35251
# [1] "# of values in matrix w/o NA:"
# [1] 12765
# [1] "# rows in final df:"
# [1] 12765
# [1] "# of values in matrix w/o NA:"
# [1] 30911
# [1] "# rows in final df:"
# [1] 30911

# %% [markdown]
# Create a list of all ko's found across all organisms. We will use the list to find the name and symbol of the ko_id's and map it back to the organism-specific tables made above.

# %%
#create a df of all unique ko's found for all annotations
all.ko <- bind_rows(ko4, ko6,ko8,ko13) %>% select(ko_id)

all.ko <- distinct(all.ko, ko_id, .keep_all = T)
#so that bash will read my file correctly, I need to start with ko= 
#and surround all ko_id's by a single quote
kk=c('ko= ')
q=c('"')
all.ko=rbind(kk, q, all.ko, q)
#write to a .txt file with ko_id's separated by a space

write.table(all.ko, "../kegg_names/all.ko.txt", quote=F, sep=" ", eol=" ", row.names = FALSE, col.names = FALSE)

# %% [markdown]
# # a total of 7218 rows, or ko_id's

# %%
#read in table with name and symbol matches to kegg ko's
#make tidy
ko_def <- read.delim("../kegg_names/ko_pathways.txt", head=F,sep = ";")
id <- str_extract(ko_def$V1,'K[[:digit:]]*')
sym <- str_remove(ko_def$V1, 'ko:K[[:digit:]]*')
ko_def <- data.frame(ko_id = id, symbol=sym, name=ko_def$V2)
isip=data.frame(ko_id=c('isip1a','isip_2a','isip_3'), 
                symbol=c('isip_1a','isip_2a','isip_3'),
                name=c('Iron stress induced protein 1a',
                       'Iron stress induced protein 2a', 'Iron stress induced protein 3'))
ko_def=bind_rows(ko_def, isip)
print(paste(nrow(ko_def), "    =   all unique ko's found across organisms"))
write.csv(ko_def,'../kegg_names/ko_def.csv', row.names=F)
tail(ko_def)
# Out:
# [1] "7191     =   all unique ko's found across organisms"
#      ko_id   symbol  name
# 7186 K11287   TSPYL4  TSPY-like 4
# 7187 K11288   TSPYL5  TSPY-like 5
# 7188 K11289   TSPYL6  TSPY-like 6
# 7189 isip1a  isip_1a Iron stress induced protein 1a
# 7190 isip_2a isip_2a Iron stress induced protein 2a
# 7191 isip_3  isip_3  Iron stress induced protein 3

# %% [markdown]
# # Now we have tidy df of query and annotation for mapping back to counts. We need to add the ISIP annotations though.
# ## Read in isip isoform annotations and make a tidy df of all isip isoforms for each organism
# Check that isip's were also counted by Salmon, remove any which were not

# %%
## read in the files
dir <- "/work/nclab/lucy/SAB/Annotation/eggnog/isip/pep_hit/"

read.isip <- function(org, prot){
    f = t(read.delim(file=paste(dir, org, 'isip', prot,'_hits.txt', sep=""),
                 sep = ' ',header = F))
    if (nrow(f) >=1){
    f <- data.frame("orfs"=f, 
                    "ko_iteration"="ko:_1",
                    "ko_id"=paste("isip_", prot, sep=""))}
}

i41 <- read.isip("04", "1")
i41a <- read.isip("04", "1a")
i41b <- read.isip("04", "1b")
i42a <- read.isip("04", "2a")
i43 <- read.isip("04", "3")
isip4 <- rbind(i41a, i41b, i42a, i43)
isip4 <- distinct(isip4, orfs, .keep_all = T)

i81 <- read.isip("08", "1")
i81a <- read.isip("08", "1a")
i81b <- read.isip("08", "1b")
i82a <- read.isip("08", "2a")
i83 <- read.isip("08", "3")
isip8 <- rbind( i81a, i81b, i82a, i83)  
isip8 <- distinct(isip8, orfs, .keep_all = T)


i61 <- read.isip("06", "1")
i61a <- read.isip("06", "1a")
i61b <- read.isip("06", "1b")
i62a <- read.isip("06", "2a")
i63 <- read.isip("06", "3")
isip6 <- rbind(i61a, i61b, i62a, i63)
isip6 <- distinct(isip6, orfs, .keep_all = T)

i132a <- read.isip("13", "2a")
i133 <- read.isip("13", "3")
isip13 <- rbind(i132a, i133)
isip13 <- distinct(isip13, orfs, .keep_all = T)

# %% [markdown]
# ## Create df with ko_id and names mapped to ORF's of each organism
# add the isip proteins to ko dataframe, checking not to repeat if the orf was already annotated. (should I replace annotation with isip?)
#
# 1. Merge full ko definition list with ko's in organism using many-to-one merge relationship.  Organism's ko df have repeated ko_id, as the same annotation could be matched to multiple ORFs. So many rows in organisms's df may match to one row in full ko definition df. The column ko_id is named the same for both objects and will be used to merge the two dataframes. For this we use dplyr's left-join with relationship=many-to-one.
#
# 2. Isip df and ko df have column query in common. We create a list of ORF's that the isip df and ko df have in common. isip rows are added to ko df for those ORFs not in common.

# %%
combine_save <- function(isip, ko_df, org){
    
    ko_fin <- bind_rows(ko_df, isip)
 
    write.csv(ko_fin, paste("../kegg_names/ko", org,"_ls.csv", sep=""), row.names=F)
    print(nrow(ko_fin))
    print(nrow(ko_df)+nrow(isip))
}


ko4_def <- combine_save(isip4, ko4, "4")
ko8_def <- combine_save(isip8, ko8, "8")
ko6_def <- combine_save(isip6, ko6, "6")
ko13_def <- combine_save(isip13, ko13, "13")
# Out:
# [1] 14312
# [1] 14312
# [1] 12787
# [1] 12787
# [1] 35262
# [1] 35262
# [1] 30920
# [1] 30920

# %% [markdown]
# # Now we have a df with all possible ko annotations, including the isip proteins, associated with orf's
#
# ## this will be now used in creating figures.

# %%
emap.ko4 <- emap4[,c('orfs', 'KEGG_ko')]
ko4_def$name <- gsub(" \\[EC.*\\]", "", ko4_def$name)
ko.sum <- ko4_def %>% group_by(orfs)%>% summarize('symbol'=str_flatten(symbol, collaps="; "), 'name'= str_flatten(name, collaps="; "))
ko.na <- data.frame('orfs'=emap.ko4[(emap.ko4$orfs %in% ko.sum$orfs)==FALSE, 'orfs'], 'symbol'=NA, 'name'=NA)
full.anno <- rbind(ko.sum, ko.na )
nrow(emap4)
nrow(full.anno)

# %%
#read in table with name and symbol matches to kegg ko's
#make tidy
br_def <- read.csv("../kegg_names/brite_def.csv", header = FALSE)
head(br_def)
id <- str_extract(br_def$V1,'K[[:digit:]]*')
sym <- str_remove(br_def$V1, 'ko:K[[:digit:]]*')
br_def <- data.frame(br_id = id, symbol=sym, name=br_def$V2)

#write.csv(ko_def,"../kegg_names/br_def.csv", row.names=F)

print(paste(nrow(br_def), "     =   all unique BRITEs found across organisms"))
dim(br_def)
head(br_def)

# %%
clean_br <- function(df){
    df <- df %>% bind_cols(split_into_multiple(.$BRITE, ",", "br:")) %>%
           select("orfs", starts_with("br:_", ))
paste(head(df))
    df_clean <- pivot_longer(df, cols = !orfs, names_to = 'br_iteration',
                         values_to ='br_id' , values_drop_na=TRUE)
        df_clean$br_id <- gsub('br:', '', df_clean$br_id)
    df_clean
    }

clean_mods <- function(df){
    df <- df %>% bind_cols(split_into_multiple(.$KEGG_Module, ",", "mo:")) %>%
           select("orfs", starts_with("mo:_", ))
paste(head(df))
    df_clean <- pivot_longer(df, cols = !orfs, names_to = 'mo_iteration',
                         values_to ='mo_id' , values_drop_na=TRUE)
        df_clean$mo_id <- gsub('mo:', '', df_clean$mo_id)
    df_clean
    }

clean_paths <- function(df){
    df <- df %>% bind_cols(split_into_multiple(.$KEGG_Pathway, ",", "path:")) %>%
           select("orfs", starts_with("path:_", ))
paste(head(df))
    df_clean <- pivot_longer(df, cols = !orfs, names_to = 'path_iteration',
                         values_to ='path_id' , values_drop_na=TRUE)
        df_clean$path_id <- gsub('path:', '', df_clean$path_id)
    df_clean
    }

br4 <- clean_br(paths4)
br8 <- clean_br(paths8)
br6 <- clean_br(paths6)
br13 <- clean_br(paths13)

all.br <- bind_rows(br4, br6, br8, br13) %>% select(br_id)
all.br <- distinct(all.br, br_id)
#write to a .txt file with path_id's separated by a space 
 write.table(paste("brite=", paste(all.br$br_id, sep=" ", collapse = " ")), "all.brite.txt", row.names = FALSE, col.names = FALSE)


mo4 <- clean_mods(paths4)
mo8 <- clean_mods(paths8)
mo6 <- clean_mods(paths6)
mo13 <- clean_mods(paths13)

all.mo <- bind_rows(mo4, mo6, mo8, mo13) %>% select(mo_id)
all.mo <- distinct(all.mo, mo_id)
#write to a .txt file with path_id's separated by a space 
 write.table(paste("module=", paste(all.mo$mo_id, sep=" ", collapse = " ")), "all.modules.txt", row.names = FALSE, col.names = FALSE)


pa4 <- clean_paths(paths4)
pa8 <- clean_paths(paths8)
pa6 <- clean_paths(paths6)
pa13 <- clean_paths(paths13)

all.path <- bind_rows(pa4, pa6,pa8,pa13) %>% select(path_id)
all.path <- distinct(all.path, path_id)
#write to a .txt file with path_id's separated by a space 
 write.table(paste("pathway=", paste(all.path$path_id, sep=" ", collapse = " ")), "all.path.txt", row.names = FALSE, col.names = FALSE)

# %% [markdown]
# # Using Kegg api for Kegg annotations
# Imported csv files of modules, paths, and individual ko's, which are not associated with a path or module, have associated subcategories and broad categories which I am interested in. To get the module or path name, all of the ko's and thier names and symbols from the module or path code, we loop through each module/path code and using Kegg api, extract this information. Because pathways and modules are associated with one annother, we will keep these tables seperate
# ## After running each loop, we should have a dataframe for each original file with a columns:
# - ko_id
# - name
# - symbol
# - pathway/module
# - sub_category
# - broad_category
# ## Extract all ko's from tables which appear in at least one sample
# We will use the resulting tables for subsetting data later in making heat maps. We can create heat maps based on pathway, module, or category.

# %%
mod_man=read.csv('../kegg_names//subcategories_ko.csv')[,1:3]
head(mod_man)
# Out:
#   ko_id  sub_category               broad_category
# 1 K11959 Urea transporter           Nitrogen Metabolism
# 2 K08907 Light harvesting complex I Photosynthesis
# 3 K08908 Light harvesting complex I Photosynthesis
# 4 K08909 Light harvesting complex I Photosynthesis
# 5 K08910 Light harvesting complex I Photosynthesis
# 6 K08911 Light harvesting complex I Photosynthesis

# %%
#1. for manually made modules ko's
## find name and symbol for each
## add name and symbol to dataframe
mod_man=read.csv('../kegg_names//subcategories_ko.csv')[,1:3]
dim(mod_man)
url=c("https://rest.kegg.jp/")
symbol=list()
ko_id=list()
name=list()

for (i in mod_man$ko_id){
    #m=c(keggFind('ko',i))
    m = getURL(paste(url,'find/ko/', i, sep=''))
    m = str_remove(m, 'ko:K[[:digit:]]{5}\t')
    ko_id=c(ko_id,i)
    symbol=c(symbol, str_remove(str_extract(string = m, pattern = '.+.*;'),';'))
    name=c(name,str_remove(str_extract(string = m, pattern = '; [[:alnum:]]+.*'),'; '))
    }

mod_ko=data.frame('ko_id'=unlist(ko_id),
                  'symbol'= unlist(symbol),
                  'name'= str_remove(unlist(name),'\n'))
mod_man=left_join(mod_man,mod_ko, by='ko_id')
mod_man=mutate(mod_man, Path=NA, path_name=mod_man$sub_category)
head(mod_man)
tail(mod_man)
# Out:
# [1] 26  3
#   ko_id  sub_category               broad_category      symbol
# 1 K11959 Urea transporter           Nitrogen Metabolism urtA
# 2 K08907 Light harvesting complex I Photosynthesis      LHCA1
# 3 K08908 Light harvesting complex I Photosynthesis      LHCA2
# 4 K08909 Light harvesting complex I Photosynthesis      LHCA3
# 5 K08910 Light harvesting complex I Photosynthesis      LHCA4
# 6 K08911 Light harvesting complex I Photosynthesis      LHCA5
#   name                                                         Path
# 1 urea transport system substrate-binding protein              NA
# 2 light-harvesting complex I chlorophyll a/b binding protein 1 NA
# 3 light-harvesting complex I chlorophyll a/b binding protein 2 NA
# 4 light-harvesting complex I chlorophyll a/b binding protein 3 NA
# 5 light-harvesting complex I chlorophyll a/b binding protein 4 NA
# 6 light-harvesting complex I chlorophyll a/b binding protein 5 NA
#   path_name
# 1 Urea transporter
# 2 Light harvesting complex I
# 3 Light harvesting complex I
# 4 Light harvesting complex I
# 5 Light harvesting complex I
# 6 Light harvesting complex I
#    ko_id  sub_category             broad_category      symbol
# 21 K26552 Nirate/Nitrite transport Nitrogen Metabolism NPF2, GTR, NRT1
# 22 K26553 Nirate/Nitrite transport Nitrogen Metabolism NPF3, NITR, NRT1
# 23 K26548 Nirate/Nitrite transport Nitrogen Metabolism NPF4, NRT1
# 24 K26562 Nirate/Nitrite transport Nitrogen Metabolism NPF5, NRT1, NAET
# 25 K26549 Nirate/Nitrite transport Nitrogen Metabolism NPF6, NRT1
# 26 K26554 Nirate/Nitrite transport Nitrogen Metabolism NPF7, NRT1
#    name
# 21 MFS transporter, POT/PTR family, nitrate/chloride/glucosinolate transporter
# 22 MFS transporter, POT/PTR family, nitrite transporter
# 23 MFS transporter, POT/PTR family, nitrate transporter
# 24 MFS transporter, POT/PTR family, peptide/nitrate/nicotianamine transporter
# 25 MFS transporter, POT/PTR family, nitrate transporter
# 26 MFS transporter, POT/PTR family, low-affinity nitrate transporter
#    Path path_name
# 21 NA   Nirate/Nitrite transport
# 22 NA   Nirate/Nitrite transport
# 23 NA   Nirate/Nitrite transport
# 24 NA   Nirate/Nitrite transport
# 25 NA   Nirate/Nitrite transport
# 26 NA   Nirate/Nitrite transport

# %%
#2. Kegg modules
## Get name for each module
## add module name to dataframe
## get list of all ko's for each module
## get ko name and symbol for each module
sub_module=read.csv("../kegg_names/subcategories_module.csv")
nrow(sub_module)
url=c("https://rest.kegg.jp/")

find.mod=list()
for (i in sub_module$Module){
    #p=keggFind('module', i)
    p=getURL(paste(url,'find/module/', i, sep=''))
    find.mod=unname(c(find.mod,str_remove(p, ", .*")))
    #module=unname(c(module,str_remove(p, ", .*"))) #str_extract(p, '[[:alpha:]]+.*'))
}

module_name=data.frame('module_name'=str_remove(find.mod,'md:M[[:digit:]]{5}\t'))
sub_mod=bind_cols(sub_module, module_name)
colnames(sub_mod)[1]='Module'

p=list()
for (i in sub_mod$Module){
    link.ko=getURL(paste(url,'link/ko/', i, sep=''))
    p=c(p,link.ko)
    #p=c(p,keggLink('ko', i))
}

p=data.frame(ko_id=unlist(str_extract_all(p,'ko:K[[:digit:]]+')), 
               module=(unlist(str_extract_all(p, 'M[[:digit:]]{5}'))))

symbol=list()
name=list()
for (i in p$ko_id){
     g=getURL(paste(url,'find/ko/', i, sep=''))
   # g=keggFind('ko', i)
    symbol=c(symbol,str_remove(str_extract(unname(g), '\t.+;'), ';'))
    name=c(name, str_remove(str_extract(unname(g),'; .*'), '; '))
}

mod_ko=data.frame('Module'=p$module,
                  'ko_id'=p$ko_id,
                  'symbol'=str_remove(unlist(symbol),'\t'),
                  'name'=unlist(name))
sub_mod=left_join(mod_ko, sub_mod, by='Module')
head(sub_mod)
# Out:
# [1] 14
#   Module ko_id     symbol
# 1 M00161 ko:K02703 psbA
# 2 M00161 ko:K02706 psbD
# 3 M00161 ko:K02705 psbC
# 4 M00161 ko:K02704 psbB
# 5 M00161 ko:K02707 psbE
# 6 M00161 ko:K02708 psbF
#   name                                                         sub_category
# 1 photosystem II P680 reaction center D1 protein [EC:1.10.3.9] Photosystem II
# 2 photosystem II P680 reaction center D2 protein [EC:1.10.3.9] Photosystem II
# 3 photosystem II CP43 chlorophyll apoprotein                   Photosystem II
# 4 photosystem II CP47 chlorophyll apoprotein                   Photosystem II
# 5 photosystem II cytochrome b559 subunit alpha                 Photosystem II
# 6 photosystem II cytochrome b559 subunit beta                  Photosystem II
#   broad_category module_name
# 1 photosynthesis Photosystem II\n
# 2 photosynthesis Photosystem II\n
# 3 photosynthesis Photosystem II\n
# 4 photosynthesis Photosystem II\n
# 5 photosynthesis Photosystem II\n
# 6 photosynthesis Photosystem II\n

# %% [markdown]
# ## Pulling out pathways used for heatmaps in paper to make loop faster

# %%
sub_cat_path=read.csv('../kegg_names/subcategories_path.csv')

heatMapPath = filter(sub_cat_path, sub_category %in% c(
    'Carbon fixation in photosynthetic organisms', 'Photosynthesis', 
    'Photosynthesis-antenna proteins', 'Nitrogen metabolism', 'Carotenoid biosynthesis'))
heatMapPath
# Out:
#   Pathway  sub_category                                broad_category
# 1 map00710 Carbon fixation in photosynthetic organisms Carbon Metabolism
# 2 map00195 Photosynthesis                              Photosynthesis
# 3 map00196 Photosynthesis-antenna proteins             Photosynthesis
# 4 map00910 Nitrogen metabolism                         Nitrogen Metabolism
# 5 map00906 Carotenoid biosynthesis                     Photosynthesis

# %%
#3. pathways
## get name for each pathway
## add pathway name to dataframe
## get list of all ko's for each pathway
## get name and symbol for each ko


url=c("https://rest.kegg.jp/")
find.path=list()
for (i in heatMapPath$Pathway){
    p=getURL(paste(url,'find/pathway/', i, sep=''))
    find.path=unname(c(find.path,p))
}

path_name=data.frame('path_name'=str_remove(find.path,'path:map[[:digit:]]{5}\t'))
path_name$path_name=str_remove(path_name$path_name, '\n')
head(path_name)
sub_path=bind_cols(heatMapPath, path_name)
colnames(sub_path)[1]='Path'

p=list()
for (i in sub_path$Path){
    link.ko=getURL(paste(url,'link/ko/', i, sep=''))
    #link.ko=str_extract(p, 'ko:K[[:digit:]]+')
    p=c(p,link.ko)
}

p=data.frame(ko_id=unlist(str_extract_all(p,'K[[:digit:]]+')), 
               path=(unlist(str_extract_all(p, 'map[[:digit:]]{5}')))) 
symbol=list()
name=list()
for (i in p$ko_id){
    g=getURL(paste(url,'find/ko/', i, sep=''))
    symbol=c(symbol,str_remove(str_extract(unname(g), '\t.+;'), ';'))
    name=c(name, str_remove(str_extract(unname(g),'; .*'), '; '))
}
path_ko=data.frame('Path'=p$path,
                   'ko_id'=p$ko_id,
                   'symbol'=str_remove(unlist(symbol),'\t'),
                   'name'= str_remove(unlist(name), '\\[EC:.*\\]'))

sub_path=left_join(path_ko, sub_path, by='Path', relationship='many-to-many')

head(sub_path)
dim(sub_path)

## add fld genes 
flavodoxin=data.frame(Path='map00195', ko_id=c('K03839','K03840','K21567','K00528'), 
                      symbol=c('fldA, nifF, isiB','fldB','fnr','fpr'), 
                      name=c('flavodoxin I','flavodoxin II','ferredoxin/flavodoxin---NADP+ reductase',
                            'ferredoxin/flavodoxin---NADP+ reductase'), sub_category='Photosynthesis',
                     broad_category='photosynthesis', path_name='Photosynthesis')
sub_path=bind_rows(sub_path, flavodoxin) 

tail(sub_path)
dim(sub_path)
filter(sub_path, path_name=='Photosynthesis')
# Out:
#   path_name
# 1 Carbon fixation in photosynthetic organisms
# 2 Photosynthesis
# 3 Photosynthesis - antenna proteins
# 4 Nitrogen metabolism
# 5 Carotenoid biosynthesis
#   Path     ko_id  symbol
# 1 map00710 K00024 mdh
# 2 map00710 K00025 MDH1
# 3 map00710 K00026 MDH2
# 4 map00710 K00028 E1.1.1.39
# 5 map00710 K00029 maeB
# 6 map00710 K00051 E1.1.1.82
#   name
# 1 malate dehydrogenase
# 2 malate dehydrogenase
# 3 malate dehydrogenase
# 4 malate dehydrogenase (decarboxylating)
# 5 malate dehydrogenase (oxaloacetate-decarboxylating)(NADP+)
# 6 malate dehydrogenase (NADP+)
#   sub_category                                broad_category
# 1 Carbon fixation in photosynthetic organisms Carbon Metabolism
# 2 Carbon fixation in photosynthetic organisms Carbon Metabolism
# 3 Carbon fixation in photosynthetic organisms Carbon Metabolism
# 4 Carbon fixation in photosynthetic organisms Carbon Metabolism
# 5 Carbon fixation in photosynthetic organisms Carbon Metabolism
# 6 Carbon fixation in photosynthetic organisms Carbon Metabolism
#   path_name
# 1 Carbon fixation in photosynthetic organisms
# 2 Carbon fixation in photosynthetic organisms
# 3 Carbon fixation in photosynthetic organisms
# 4 Carbon fixation in photosynthetic organisms
# 5 Carbon fixation in photosynthetic organisms
# 6 Carbon fixation in photosynthetic organisms
# [1] 264   7
#     Path     ko_id  symbol           name
# 263 map00906 K25073 cruO             1'-hydroxy-gamma-carotene C-4' ketolase
# 264 map00906 K25074 crtU             carotenoid chi-ring synthase
# 265 map00195 K03839 fldA, nifF, isiB flavodoxin I
# 266 map00195 K03840 fldB             flavodoxin II
# 267 map00195 K21567 fnr              ferredoxin/flavodoxin---NADP+ reductase
# 268 map00195 K00528 fpr              ferredoxin/flavodoxin---NADP+ reductase
#     sub_category            broad_category path_name
# 263 Carotenoid biosynthesis Photosynthesis Carotenoid biosynthesis
# 264 Carotenoid biosynthesis Photosynthesis Carotenoid biosynthesis
# 265 Photosynthesis          photosynthesis Photosynthesis
# 266 Photosynthesis          photosynthesis Photosynthesis
# 267 Photosynthesis          photosynthesis Photosynthesis
# 268 Photosynthesis          photosynthesis Photosynthesis
# [1] 268   7
#    Path     ko_id  symbol
# 1  map00195 K02108 ATPF0A, atpB
# 2  map00195 K02109 ATPF0B, atpF
# 3  map00195 K02110 ATPF0C, atpE
# 4  map00195 K02111 ATPF1A, atpA
# 5  map00195 K02112 ATPF1B, atpD
# 6  map00195 K02113 ATPF1D, atpH
# 7  map00195 K02114 ATPF1E, atpC
# 8  map00195 K02115 ATPF1G, atpG
# 9  map00195 K02634 petA
# 10 map00195 K02635 petB
# 11 map00195 K02636 petC
# 12 map00195 K02637 petD
# 13 map00195 K02638 petE
# 14 map00195 K02639 petF
# 15 map00195 K02640 petG
# 16 map00195 K02641 petH
# 17 map00195 K02642 petL
# 18 map00195 K02643 petM
# 19 map00195 K02689 psaA
# 20 map00195 K02690 psaB
# 21 map00195 K02691 psaC
# 22 map00195 K02692 psaD
# 23 map00195 K02693 psaE
# 24 map00195 K02694 psaF
# 25 map00195 K02695 psaH
# 26 map00195 K02696 psaI
# 27 map00195 K02697 psaJ
# 28 map00195 K02698 psaK
# 29 map00195 K02699 psaL
# 30 map00195 K02700 psaM
# ⋮  ⋮        ⋮      ⋮
# 38 map00195 K02708 psbF
# 39 map00195 K02709 psbH
# 40 map00195 K02710 psbI
# 41 map00195 K02711 psbJ
# 42 map00195 K02712 psbK
# 43 map00195 K02713 psbL
# 44 map00195 K02714 psbM
# 45 map00195 K02716 psbO
# 46 map00195 K02717 psbP
# 47 map00195 K02718 psbT
# 48 map00195 K02719 psbU
# 49 map00195 K02720 psbV
# 50 map00195 K02721 psbW
# 51 map00195 K02722 psbX
# 52 map00195 K02723 psbY
# 53 map00195 K02724 psbZ
# 54 map00195 K03541 psbR
# 55 map00195 K03542 psbS
# 56 map00195 K03689 petN
# 57 map00195 K08901 psbQ
# 58 map00195 K08902 psb27
# 59 map00195 K08903 psb28
# 60 map00195 K08904 psb28-2
# 61 map00195 K08905 psaG
# 62 map00195 K08906 petJ
# 63 map00195 K14332 psaO
# 64 map00195 K03839 fldA, nifF, isiB
# 65 map00195 K03840 fldB
# 66 map00195 K21567 fnr
# 67 map00195 K00528 fpr
#    name                                              sub_category
# 1  F-type H+-transporting ATPase subunit a           Photosynthesis
# 2  F-type H+-transporting ATPase subunit b           Photosynthesis
# 3  F-type H+-transporting ATPase subunit c           Photosynthesis
# 4  F-type H+/Na+-transporting ATPase subunit alpha   Photosynthesis
# 5  F-type H+/Na+-transporting ATPase subunit beta    Photosynthesis
# 6  F-type H+-transporting ATPase subunit delta       Photosynthesis
# 7  F-type H+-transporting ATPase subunit epsilon     Photosynthesis
# 8  F-type H+-transporting ATPase subunit gamma       Photosynthesis
# 9  apocytochrome f                                   Photosynthesis
# 10 cytochrome b6                                     Photosynthesis
# 11 cytochrome b6-f complex iron-sulfur subunit       Photosynthesis
# 12 cytochrome b6-f complex subunit 4                 Photosynthesis
# 13 plastocyanin                                      Photosynthesis
# 14 ferredoxin                                        Photosynthesis
# 15 cytochrome b6-f complex subunit 5                 Photosynthesis
# 16 ferredoxin--NADP+ reductase                       Photosynthesis
# 17 cytochrome b6-f complex subunit 6                 Photosynthesis
# 18 cytochrome b6-f complex subunit 7                 Photosynthesis
# 19 photosystem I P700 chlorophyll a apoprotein A1    Photosynthesis
# 20 photosystem I P700 chlorophyll a apoprotein A2    Photosynthesis
# 21 photosystem I iron-sulfur center                  Photosynthesis
# 22 photosystem I subunit II                          Photosynthesis
# 23 photosystem I subunit IV                          Photosynthesis
# 24 photosystem I subunit III                         Photosynthesis
# 25 photosystem I subunit VI                          Photosynthesis
# 26 photosystem I subunit VIII                        Photosynthesis
# 27 photosystem I subunit IX                          Photosynthesis
# 28 photosystem I subunit X                           Photosynthesis
# 29 photosystem I subunit XI                          Photosynthesis
# 30 photosystem I subunit XII                         Photosynthesis
# ⋮  ⋮                                                 ⋮
# 38 photosystem II cytochrome b559 subunit beta       Photosynthesis
# 39 photosystem II PsbH protein                       Photosynthesis
# 40 photosystem II PsbI protein                       Photosynthesis
# 41 photosystem II PsbJ protein                       Photosynthesis
# 42 photosystem II PsbK protein                       Photosynthesis
# 43 photosystem II PsbL protein                       Photosynthesis
# 44 photosystem II PsbM protein                       Photosynthesis
# 45 photosystem II oxygen-evolving enhancer protein 1 Photosynthesis
# 46 photosystem II oxygen-evolving enhancer protein 2 Photosynthesis
# 47 photosystem II PsbT protein                       Photosynthesis
# 48 photosystem II PsbU protein                       Photosynthesis
# 49 photosystem II cytochrome c550                    Photosynthesis
# 50 photosystem II PsbW protein                       Photosynthesis
# 51 photosystem II PsbX protein                       Photosynthesis
# 52 photosystem II PsbY protein                       Photosynthesis
# 53 photosystem II PsbZ protein                       Photosynthesis
# 54 photosystem II 10kDa protein                      Photosynthesis
# 55 photosystem II 22kDa protein                      Photosynthesis
# 56 cytochrome b6-f complex subunit 8                 Photosynthesis
# 57 photosystem II oxygen-evolving enhancer protein 3 Photosynthesis
# 58 photosystem II Psb27 protein                      Photosynthesis
# 59 photosystem II 13kDa protein                      Photosynthesis
# 60 photosystem II Psb28-2 protein                    Photosynthesis
# 61 photosystem I subunit V                           Photosynthesis
# 62 cytochrome c6                                     Photosynthesis
# 63 photosystem I subunit PsaO                        Photosynthesis
# 64 flavodoxin I                                      Photosynthesis
# 65 flavodoxin II                                     Photosynthesis
# 66 ferredoxin/flavodoxin---NADP+ reductase           Photosynthesis
# 67 ferredoxin/flavodoxin---NADP+ reductase           Photosynthesis
#    broad_category path_name
# 1  Photosynthesis Photosynthesis
# 2  Photosynthesis Photosynthesis
# 3  Photosynthesis Photosynthesis
# 4  Photosynthesis Photosynthesis
# 5  Photosynthesis Photosynthesis
# 6  Photosynthesis Photosynthesis
# 7  Photosynthesis Photosynthesis
# 8  Photosynthesis Photosynthesis
# 9  Photosynthesis Photosynthesis
# 10 Photosynthesis Photosynthesis
# 11 Photosynthesis Photosynthesis
# 12 Photosynthesis Photosynthesis
# 13 Photosynthesis Photosynthesis
# 14 Photosynthesis Photosynthesis
# 15 Photosynthesis Photosynthesis
# 16 Photosynthesis Photosynthesis
# 17 Photosynthesis Photosynthesis
# 18 Photosynthesis Photosynthesis
# 19 Photosynthesis Photosynthesis
# 20 Photosynthesis Photosynthesis
# 21 Photosynthesis Photosynthesis
# 22 Photosynthesis Photosynthesis
# 23 Photosynthesis Photosynthesis
# 24 Photosynthesis Photosynthesis
# 25 Photosynthesis Photosynthesis
# 26 Photosynthesis Photosynthesis
# 27 Photosynthesis Photosynthesis
# 28 Photosynthesis Photosynthesis
# 29 Photosynthesis Photosynthesis
# 30 Photosynthesis Photosynthesis
# ⋮  ⋮              ⋮
# 38 Photosynthesis Photosynthesis
# 39 Photosynthesis Photosynthesis
# 40 Photosynthesis Photosynthesis
# 41 Photosynthesis Photosynthesis
# 42 Photosynthesis Photosynthesis
# 43 Photosynthesis Photosynthesis
# 44 Photosynthesis Photosynthesis
# 45 Photosynthesis Photosynthesis
# 46 Photosynthesis Photosynthesis
# 47 Photosynthesis Photosynthesis
# 48 Photosynthesis Photosynthesis
# 49 Photosynthesis Photosynthesis
# 50 Photosynthesis Photosynthesis
# 51 Photosynthesis Photosynthesis
# 52 Photosynthesis Photosynthesis
# 53 Photosynthesis Photosynthesis
# 54 Photosynthesis Photosynthesis
# 55 Photosynthesis Photosynthesis
# 56 Photosynthesis Photosynthesis
# 57 Photosynthesis Photosynthesis
# 58 Photosynthesis Photosynthesis
# 59 Photosynthesis Photosynthesis
# 60 Photosynthesis Photosynthesis
# 61 Photosynthesis Photosynthesis
# 62 Photosynthesis Photosynthesis
# 63 Photosynthesis Photosynthesis
# 64 photosynthesis Photosynthesis
# 65 photosynthesis Photosynthesis
# 66 photosynthesis Photosynthesis
# 67 photosynthesis Photosynthesis

# %%
sub_path$path_name[sub_path$path_name=='Photosynthesis - antenna proteins']='Photosynthesis'

sub_path[str_detect(sub_path$symbol, "DUF"), 'sub_category'] =  "NADH dehydrogenase"
sub_path[str_detect(sub_path$symbol, "COX|cox|CYC"), 'sub_category'] = "cytochrome c"
sub_path[str_detect(sub_path$symbol, "ATP.*V"),'sub_category'] = "V-Type ATP-ase"
sub_path[str_detect(sub_path$symbol, "ATP.*F"), 'sub_category'] = "F-Type ATP-ase"

heat.path=(filter(sub_path, (ko_id %in% ko_def$ko_id)==T))

heat.path$name= str_replace_all(heat.path$name, c('light-harvesting complex I '='LHCA ','light-harvesting complex II'='LHCB',  
                                 'chlorophyll'='Chl','photosystem I '='PSI ', 'photosystem II'='PSII',
                                 'F-type .* subunit '='F-Type ATP-ase ', 'isip_'='Iron starvation induced protein ',
                                 'fructose-bisphosphate aldolase'='FBA', 'ribulose-bisphosphate carboxylase'='RuBisCO',
                                               'MFS transporter, NNP family, '=''))

urea_cycle = filter(ko_def, ko_id%in%c('K00611','K01940','K01755','K01476'))
urea_cycle = mutate(urea_cycle, 'sub_category'='Urea cycle', 'broad_category'='Nitrogen metabolism','path_name'='Nitrogen metabolism', 'Path'='map00910')
heat.path = full_join(heat.path, urea_cycle)
# Out:
# Joining with `by = join_by(Path, ko_id, symbol, name, sub_category, broad_category, path_name)`

# %%
heat.path[str_detect(heat.path$symbol, 'MDH1'), 'name'] = 'malate dehydrogenase 1'
heat.path[str_detect(heat.path$symbol, 'MDH2'), 'name'] = 'malate dehydrogenase 2'
heat.path[str_detect(heat.path$symbol, 'maeB|ppdK'), 'sub_category'] = 'CAM light'
heat.path[str_detect(heat.path$symbol, 'MDH1|MDH2|mdh|ppc'), 'sub_category'] = 'CAM dark'
heat.path[heat.path$ko_id %in% 
          c('K00855','K00927','K01100','K01601','K01623','K01624','K01783',
            'K01803','K01807','K01808','K02446','K03841','K11532','K00134',
            'K00615'), 'sub_category'] = 'Calvin cycle' 
heat.path$sub_category = str_replace(heat.path$sub_category, 'Carbon fixation in photosynthetic organisms', 'C4 Dicarboxilic acid cycle')
heat.path$name = str_remove(heat.path$name, '.(phosphorylating).')
filter(heat.path, path_name=='Carbon fixation in photosynthetic organisms')
# Out:
#    Path     ko_id  symbol
# 1  map00710 K00024 mdh
# 2  map00710 K00025 MDH1
# 3  map00710 K00026 MDH2
# 4  map00710 K00028 E1.1.1.39
# 5  map00710 K00029 maeB
# 6  map00710 K00134 GAPDH, gapA
# 7  map00710 K00615 E2.2.1.1, tktA, tktB
# 8  map00710 K00814 GPT, ALT
# 9  map00710 K00855 PRK, prkB
# 10 map00710 K00927 PGK, pgk
# 11 map00710 K01006 ppdK
# 12 map00710 K01100 E3.1.3.37
# 13 map00710 K01595 ppc
# 14 map00710 K01601 rbcL, cbbL
# 15 map00710 K01610 pckA
# 16 map00710 K01623 ALDO
# 17 map00710 K01624 FBA, fbaA
# 18 map00710 K01783 rpe, RPE
# 19 map00710 K01803 TPI, tpiA
# 20 map00710 K01807 rpiA
# 21 map00710 K01808 rpiB
# 22 map00710 K02446 glpX
# 23 map00710 K03841 FBP, fbp
# 24 map00710 K11532 glpX-SEBP
# 25 map00710 K14454 GOT1
# 26 map00710 K14455 GOT2
#    name
# 1  malate dehydrogenase
# 2  malate dehydrogenase 1
# 3  malate dehydrogenase 2
# 4  malate dehydrogenase (decarboxylating)
# 5  malate dehydrogenase (oxaloacetate-decarboxylating)(NADP+)
# 6  glyceraldehyde 3-phosphate dehydrogenase
# 7  transketolase
# 8  alanine transaminase
# 9  phosphoribulokinase
# 10 phosphoglycerate kinase
# 11 pyruvate, orthophosphate dikinase
# 12 sedoheptulose-bisphosphatase
# 13 phosphoenolpyruvate carboxylase
# 14 RuBisCO large chain
# 15 phosphoenolpyruvate carboxykinase (ATP)
# 16 FBA, class I
# 17 FBA, class II
# 18 ribulose-phosphate 3-epimerase
# 19 triosephosphate isomerase (TIM)
# 20 ribose 5-phosphate isomerase A
# 21 ribose 5-phosphate isomerase B
# 22 fructose-1,6-bisphosphatase II
# 23 fructose-1,6-bisphosphatase I
# 24 fructose-1,6-bisphosphatase II / sedoheptulose-1,7-bisphosphatase
# 25 aspartate aminotransferase, cytoplasmic
# 26 aspartate aminotransferase, mitochondrial
#    sub_category               broad_category
# 1  CAM dark                   Carbon Metabolism
# 2  CAM dark                   Carbon Metabolism
# 3  CAM dark                   Carbon Metabolism
# 4  C4 Dicarboxilic acid cycle Carbon Metabolism
# 5  CAM light                  Carbon Metabolism
# 6  Calvin cycle               Carbon Metabolism
# 7  Calvin cycle               Carbon Metabolism
# 8  C4 Dicarboxilic acid cycle Carbon Metabolism
# 9  Calvin cycle               Carbon Metabolism
# 10 Calvin cycle               Carbon Metabolism
# 11 CAM light                  Carbon Metabolism
# 12 Calvin cycle               Carbon Metabolism
# 13 CAM dark                   Carbon Metabolism
# 14 Calvin cycle               Carbon Metabolism
# 15 C4 Dicarboxilic acid cycle Carbon Metabolism
# 16 Calvin cycle               Carbon Metabolism
# 17 Calvin cycle               Carbon Metabolism
# 18 Calvin cycle               Carbon Metabolism
# 19 Calvin cycle               Carbon Metabolism
# 20 Calvin cycle               Carbon Metabolism
# 21 Calvin cycle               Carbon Metabolism
# 22 Calvin cycle               Carbon Metabolism
# 23 Calvin cycle               Carbon Metabolism
# 24 Calvin cycle               Carbon Metabolism
# 25 C4 Dicarboxilic acid cycle Carbon Metabolism
# 26 C4 Dicarboxilic acid cycle Carbon Metabolism
#    path_name
# 1  Carbon fixation in photosynthetic organisms
# 2  Carbon fixation in photosynthetic organisms
# 3  Carbon fixation in photosynthetic organisms
# 4  Carbon fixation in photosynthetic organisms
# 5  Carbon fixation in photosynthetic organisms
# 6  Carbon fixation in photosynthetic organisms
# 7  Carbon fixation in photosynthetic organisms
# 8  Carbon fixation in photosynthetic organisms
# 9  Carbon fixation in photosynthetic organisms
# 10 Carbon fixation in photosynthetic organisms
# 11 Carbon fixation in photosynthetic organisms
# 12 Carbon fixation in photosynthetic organisms
# 13 Carbon fixation in photosynthetic organisms
# 14 Carbon fixation in photosynthetic organisms
# 15 Carbon fixation in photosynthetic organisms
# 16 Carbon fixation in photosynthetic organisms
# 17 Carbon fixation in photosynthetic organisms
# 18 Carbon fixation in photosynthetic organisms
# 19 Carbon fixation in photosynthetic organisms
# 20 Carbon fixation in photosynthetic organisms
# 21 Carbon fixation in photosynthetic organisms
# 22 Carbon fixation in photosynthetic organisms
# 23 Carbon fixation in photosynthetic organisms
# 24 Carbon fixation in photosynthetic organisms
# 25 Carbon fixation in photosynthetic organisms
# 26 Carbon fixation in photosynthetic organisms

# %%
heat.path[str_detect(heat.path$name, 'carbonic anhydrase'), 'sub_category'] = 'Carbonic anhydrase'
heat.path[str_detect(heat.path$name, 'nitrate/nitrite transport'), 'sub_category'] = 'Nitrogen transporters'
heat.path[str_detect(heat.path$name, 'glutamate|glutamine'), 'sub_category'] = 'GS/GOGAT and GDH'
heat.path[str_detect(heat.path$name, 'nitrite reductase'), 'sub_category'] = 'Nitrite reductase'
heat.path[str_detect(heat.path$name, 'nitrate reductase'), 'sub_category'] = 'Nitrite reductase'
heat.path[str_detect(heat.path$symbol, 'CPS1'), 'sub_category'] = 'Urea cycle'
heat.path$name = str_remove(heat.path$name, '\\[.*\\]')
filter(heat.path, path_name=='Nitrogen metabolism')
# Out:
#    Path     ko_id  symbol
# 1  map00910 K00261 GLUD1_2, gdhA
# 2  map00910 K00262 E1.4.1.4, gdhA
# 3  map00910 K00264 GLT1
# 4  map00910 K00265 gltB
# 5  map00910 K00266 gltD
# 6  map00910 K00284 GLU, gltS
# 7  map00910 K00362 nirB
# 8  map00910 K00366 nirA
# 9  map00910 K00368 nirK
# 10 map00910 K00372 nasC, nasA
# 11 map00910 K00459 ncd2, npd
# 12 map00910 K01455 E3.5.1.49
# 13 map00910 K01501 E3.5.5.1
# 14 map00910 K01672 CA
# 15 map00910 K01673 cynT, can
# 16 map00910 K01674 cah
# 17 map00910 K01725 cynS
# 18 map00910 K01915 glnA, GLUL
# 19 map00910 K01948 CPS1
# 20 map00910 K02575 NRT2, narK, nrtP, nasA
# 21 map00910 K10534 NR
# 22 map00910 K15371 GDH2
# 23 map00910 K15576 nrtA, nasF, cynA
# 24 map00910 K15577 nrtB, nasE, cynB
# 25 map00910 K15578 nrtC, nasD
# 26 map00910 K15579 nrtD, cynD
# 27 map00910 K15877 CYP55
# 28 map00910 K01755  argH, ASL
# 29 map00910 K01940  argG, ASS1
# 30 map00910 K00611  OTC, argF, argI
# 31 map00910 K01476  E3.5.3.1, rocF, arg
#    name
# 1  glutamate dehydrogenase (NAD(P)+)
# 2  glutamate dehydrogenase (NADP+)
# 3  glutamate synthase (NADH)
# 4  glutamate synthase (NADPH) large chain
# 5  glutamate synthase (NADPH) small chain
# 6  glutamate synthase (ferredoxin)
# 7  nitrite reductase (NADH) large subunit
# 8  ferredoxin-nitrite reductase
# 9  nitrite reductase (NO-forming)
# 10 assimilatory nitrate reductase catalytic subunit
# 11 nitronate monooxygenase
# 12 formamidase
# 13 nitrilase
# 14 carbonic anhydrase
# 15 carbonic anhydrase
# 16 carbonic anhydrase
# 17 cyanate lyase
# 18 glutamine synthetase
# 19 carbamoyl-phosphate synthase (ammonia)
# 20 nitrate/nitrite transporter
# 21 nitrate reductase (NAD(P)H)
# 22 glutamate dehydrogenase
# 23 nitrate/nitrite transport system substrate-binding protein
# 24 nitrate/nitrite transport system permease protein
# 25 nitrate/nitrite transport system ATP-binding protein
# 26 nitrate/nitrite transport system ATP-binding protein
# 27 fungal nitric oxide reductase
# 28  argininosuccinate lyase
# 29  argininosuccinate synthase
# 30  ornithine carbamoyltransferase
# 31  arginase
#    sub_category          broad_category      path_name
# 1  GS/GOGAT and GDH      Nitrogen Metabolism Nitrogen metabolism
# 2  GS/GOGAT and GDH      Nitrogen Metabolism Nitrogen metabolism
# 3  GS/GOGAT and GDH      Nitrogen Metabolism Nitrogen metabolism
# 4  GS/GOGAT and GDH      Nitrogen Metabolism Nitrogen metabolism
# 5  GS/GOGAT and GDH      Nitrogen Metabolism Nitrogen metabolism
# 6  GS/GOGAT and GDH      Nitrogen Metabolism Nitrogen metabolism
# 7  Nitrite reductase     Nitrogen Metabolism Nitrogen metabolism
# 8  Nitrite reductase     Nitrogen Metabolism Nitrogen metabolism
# 9  Nitrite reductase     Nitrogen Metabolism Nitrogen metabolism
# 10 Nitrite reductase     Nitrogen Metabolism Nitrogen metabolism
# 11 Nitrogen metabolism   Nitrogen Metabolism Nitrogen metabolism
# 12 Nitrogen metabolism   Nitrogen Metabolism Nitrogen metabolism
# 13 Nitrogen metabolism   Nitrogen Metabolism Nitrogen metabolism
# 14 Carbonic anhydrase    Nitrogen Metabolism Nitrogen metabolism
# 15 Carbonic anhydrase    Nitrogen Metabolism Nitrogen metabolism
# 16 Carbonic anhydrase    Nitrogen Metabolism Nitrogen metabolism
# 17 Nitrogen metabolism   Nitrogen Metabolism Nitrogen metabolism
# 18 GS/GOGAT and GDH      Nitrogen Metabolism Nitrogen metabolism
# 19 Urea cycle            Nitrogen Metabolism Nitrogen metabolism
# 20 Nitrogen transporters Nitrogen Metabolism Nitrogen metabolism
# 21 Nitrite reductase     Nitrogen Metabolism Nitrogen metabolism
# 22 GS/GOGAT and GDH      Nitrogen Metabolism Nitrogen metabolism
# 23 Nitrogen transporters Nitrogen Metabolism Nitrogen metabolism
# 24 Nitrogen transporters Nitrogen Metabolism Nitrogen metabolism
# 25 Nitrogen transporters Nitrogen Metabolism Nitrogen metabolism
# 26 Nitrogen transporters Nitrogen Metabolism Nitrogen metabolism
# 27 Nitrogen metabolism   Nitrogen Metabolism Nitrogen metabolism
# 28 Urea cycle            Nitrogen metabolism Nitrogen metabolism
# 29 Urea cycle            Nitrogen metabolism Nitrogen metabolism
# 30 Urea cycle            Nitrogen metabolism Nitrogen metabolism
# 31 Urea cycle            Nitrogen metabolism Nitrogen metabolism

# %%
heat.path[str_detect(heat.path$symbol, 'psa'), 'sub_category'] = 'PSI'
heat.path[str_detect(heat.path$symbol, 'psb'), 'sub_category'] = 'PSII'
heat.path[str_detect(heat.path$symbol, 'LHCA'), 'sub_category'] = 'LHCA'
heat.path[str_detect(heat.path$symbol, 'LHCB'), 'sub_category'] = 'LHCB'
heat.path$sub_category = str_replace(heat.path$sub_category, 'Photosynthesis', 'Electron transport chain')
heat.path[str_detect(heat.path$sub_category, 'F-Type ATP-ase'), 'path_name'] = 'F-Type ATP-ase'

filter(heat.path, path_name=='Photosynthesis')
# Out:
#    Path     ko_id  symbol
# 1  map00195 K02634 petA
# 2  map00195 K02636 petC
# 3  map00195 K02639 petF
# 4  map00195 K02641 petH
# 5  map00195 K02689 psaA
# 6  map00195 K02690 psaB
# 7  map00195 K02692 psaD
# 8  map00195 K02693 psaE
# 9  map00195 K02698 psaK
# 10 map00195 K02703 psbA
# 11 map00195 K02704 psbB
# 12 map00195 K02705 psbC
# 13 map00195 K02706 psbD
# 14 map00195 K02714 psbM
# 15 map00195 K02716 psbO
# 16 map00195 K02717 psbP
# 17 map00195 K02719 psbU
# 18 map00195 K08901 psbQ
# 19 map00195 K08902 psb27
# 20 map00195 K08903 psb28
# 21 map00195 K08906 petJ
# 22 map00196 K08907 LHCA1
# 23 map00196 K08908 LHCA2
# 24 map00196 K08910 LHCA4
# 25 map00196 K08911 LHCA5
# 26 map00196 K08914 LHCB3
# 27 map00196 K08916 LHCB5
# 28 map00196 K08917 LHCB6
# 29 map00196 K14172 LHCB7
# 30 map00195 K03839 fldA, nifF, isiB
# 31 map00195 K00528 fpr
#    name                                         sub_category
# 1  apocytochrome f                              Electron transport chain
# 2  cytochrome b6-f complex iron-sulfur subunit  Electron transport chain
# 3  ferredoxin                                   Electron transport chain
# 4  ferredoxin--NADP+ reductase                  Electron transport chain
# 5  psa P700 Chl a apoprotein A1                 PSI
# 6  psa P700 Chl a apoprotein A2                 PSI
# 7  psa subunit II                               PSI
# 8  psa subunit IV                               PSI
# 9  psa subunit X                                PSI
# 10 psb P680 reaction center D1 protein          PSII
# 11 psb CP47 Chl apoprotein                      PSII
# 12 psb CP43 Chl apoprotein                      PSII
# 13 psb P680 reaction center D2 protein          PSII
# 14 psb PsbM protein                             PSII
# 15 psb oxygen-evolving enhancer protein 1       PSII
# 16 psb oxygen-evolving enhancer protein 2       PSII
# 17 psb PsbU protein                             PSII
# 18 psb oxygen-evolving enhancer protein 3       PSII
# 19 psb Psb27 protein                            PSII
# 20 psb 13kDa protein                            PSII
# 21 cytochrome c6                                Electron transport chain
# 22 LHCA Chl a/b binding protein 1               LHCA
# 23 LHCA Chl a/b binding protein 2               LHCA
# 24 LHCA Chl a/b binding protein 4               LHCA
# 25 LHCA Chl a/b binding protein 5               LHCA
# 26 LHCB Chl a/b binding protein 3               LHCB
# 27 LHCB Chl a/b binding protein 5               LHCB
# 28 LHCB Chl a/b binding protein 6               LHCB
# 29 LHCB Chl a/b binding protein 7               LHCB
# 30 flavodoxin I                                 Electron transport chain
# 31 ferredoxin/flavodoxin---NADP+ reductase      Electron transport chain
#    broad_category path_name
# 1  Photosynthesis Photosynthesis
# 2  Photosynthesis Photosynthesis
# 3  Photosynthesis Photosynthesis
# 4  Photosynthesis Photosynthesis
# 5  Photosynthesis Photosynthesis
# 6  Photosynthesis Photosynthesis
# 7  Photosynthesis Photosynthesis
# 8  Photosynthesis Photosynthesis
# 9  Photosynthesis Photosynthesis
# 10 Photosynthesis Photosynthesis
# 11 Photosynthesis Photosynthesis
# 12 Photosynthesis Photosynthesis
# 13 Photosynthesis Photosynthesis
# 14 Photosynthesis Photosynthesis
# 15 Photosynthesis Photosynthesis
# 16 Photosynthesis Photosynthesis
# 17 Photosynthesis Photosynthesis
# 18 Photosynthesis Photosynthesis
# 19 Photosynthesis Photosynthesis
# 20 Photosynthesis Photosynthesis
# 21 Photosynthesis Photosynthesis
# 22 Photosynthesis Photosynthesis
# 23 Photosynthesis Photosynthesis
# 24 Photosynthesis Photosynthesis
# 25 Photosynthesis Photosynthesis
# 26 Photosynthesis Photosynthesis
# 27 Photosynthesis Photosynthesis
# 28 Photosynthesis Photosynthesis
# 29 Photosynthesis Photosynthesis
# 30 photosynthesis Photosynthesis
# 31 photosynthesis Photosynthesis

# %%
heat.path[str_detect(heat.path$name, 'violaxanthin|zeaxanthin'), 'path_name'] = 'Photosynthesis'
heat.path[str_detect(heat.path$name, 'violaxanthin|zeaxanthin'), 'sub_category'] = 'Xanthophyll cycle'

filter(heat.path, path_name=='Photosynthesis')
# Out:
#    Path     ko_id  symbol
# 1  map00195 K02634 petA
# 2  map00195 K02636 petC
# 3  map00195 K02639 petF
# 4  map00195 K02641 petH
# 5  map00195 K02689 psaA
# 6  map00195 K02690 psaB
# 7  map00195 K02692 psaD
# 8  map00195 K02693 psaE
# 9  map00195 K02698 psaK
# 10 map00195 K02703 psbA
# 11 map00195 K02704 psbB
# 12 map00195 K02705 psbC
# 13 map00195 K02706 psbD
# 14 map00195 K02714 psbM
# 15 map00195 K02716 psbO
# 16 map00195 K02717 psbP
# 17 map00195 K02719 psbU
# 18 map00195 K08901 psbQ
# 19 map00195 K08902 psb27
# 20 map00195 K08903 psb28
# 21 map00195 K08906 petJ
# 22 map00196 K08907 LHCA1
# 23 map00196 K08908 LHCA2
# 24 map00196 K08910 LHCA4
# 25 map00196 K08911 LHCA5
# 26 map00196 K08914 LHCB3
# 27 map00196 K08916 LHCB5
# 28 map00196 K08917 LHCB6
# 29 map00196 K14172 LHCB7
# 30 map00906 K09838 ZEP, ABA1
# 31 map00906 K09839 VDE, NPQ1
# 32 map00195 K03839 fldA, nifF, isiB
# 33 map00195 K00528 fpr
#    name                                         sub_category
# 1  apocytochrome f                              Electron transport chain
# 2  cytochrome b6-f complex iron-sulfur subunit  Electron transport chain
# 3  ferredoxin                                   Electron transport chain
# 4  ferredoxin--NADP+ reductase                  Electron transport chain
# 5  psa P700 Chl a apoprotein A1                 PSI
# 6  psa P700 Chl a apoprotein A2                 PSI
# 7  psa subunit II                               PSI
# 8  psa subunit IV                               PSI
# 9  psa subunit X                                PSI
# 10 psb P680 reaction center D1 protein          PSII
# 11 psb CP47 Chl apoprotein                      PSII
# 12 psb CP43 Chl apoprotein                      PSII
# 13 psb P680 reaction center D2 protein          PSII
# 14 psb PsbM protein                             PSII
# 15 psb oxygen-evolving enhancer protein 1       PSII
# 16 psb oxygen-evolving enhancer protein 2       PSII
# 17 psb PsbU protein                             PSII
# 18 psb oxygen-evolving enhancer protein 3       PSII
# 19 psb Psb27 protein                            PSII
# 20 psb 13kDa protein                            PSII
# 21 cytochrome c6                                Electron transport chain
# 22 LHCA Chl a/b binding protein 1               LHCA
# 23 LHCA Chl a/b binding protein 2               LHCA
# 24 LHCA Chl a/b binding protein 4               LHCA
# 25 LHCA Chl a/b binding protein 5               LHCA
# 26 LHCB Chl a/b binding protein 3               LHCB
# 27 LHCB Chl a/b binding protein 5               LHCB
# 28 LHCB Chl a/b binding protein 6               LHCB
# 29 LHCB Chl a/b binding protein 7               LHCB
# 30 zeaxanthin epoxidase                         Xanthophyll cycle
# 31 violaxanthin de-epoxidase                    Xanthophyll cycle
# 32 flavodoxin I                                 Electron transport chain
# 33 ferredoxin/flavodoxin---NADP+ reductase      Electron transport chain
#    broad_category path_name
# 1  Photosynthesis Photosynthesis
# 2  Photosynthesis Photosynthesis
# 3  Photosynthesis Photosynthesis
# 4  Photosynthesis Photosynthesis
# 5  Photosynthesis Photosynthesis
# 6  Photosynthesis Photosynthesis
# 7  Photosynthesis Photosynthesis
# 8  Photosynthesis Photosynthesis
# 9  Photosynthesis Photosynthesis
# 10 Photosynthesis Photosynthesis
# 11 Photosynthesis Photosynthesis
# 12 Photosynthesis Photosynthesis
# 13 Photosynthesis Photosynthesis
# 14 Photosynthesis Photosynthesis
# 15 Photosynthesis Photosynthesis
# 16 Photosynthesis Photosynthesis
# 17 Photosynthesis Photosynthesis
# 18 Photosynthesis Photosynthesis
# 19 Photosynthesis Photosynthesis
# 20 Photosynthesis Photosynthesis
# 21 Photosynthesis Photosynthesis
# 22 Photosynthesis Photosynthesis
# 23 Photosynthesis Photosynthesis
# 24 Photosynthesis Photosynthesis
# 25 Photosynthesis Photosynthesis
# 26 Photosynthesis Photosynthesis
# 27 Photosynthesis Photosynthesis
# 28 Photosynthesis Photosynthesis
# 29 Photosynthesis Photosynthesis
# 30 Photosynthesis Photosynthesis
# 31 Photosynthesis Photosynthesis
# 32 photosynthesis Photosynthesis
# 33 photosynthesis Photosynthesis

# %%
unique(heat.path$path_name)
write.csv(heat.path, '../kegg_names/pathwaysHeatMap.csv', row.names=F)
# Out:
# [1] "Carbon fixation in photosynthetic organisms"
# [2] "F-Type ATP-ase"
# [3] "Photosynthesis"
# [4] "Nitrogen metabolism"
# [5] "Carotenoid biosynthesis"

# %%
all(heat.path$ko_id %in% ko_def$ko_id)
dim(heat.path)
# Out:
# [1] TRUE
# [1] 113   7

# %% [markdown]
# ## Combine kegg module and manual module tables

# %% [markdown]
# ### Now I have mod/path code and name, sub and broad categorie and ko_id, name and symbol for each
# using the ko_id find matches in my data, some ko's might be repeated in different categories so make sure they are repeated in each category
#
# ## in the end I want a df with links of ko's in my data, name, symbol, path/module code and name, subcategory, broad category
# i can use this when refering to data for plotting
# ## Make sure to check that genes i am interested in like lhp and ferredoxin actually showed up! check differences in length between original list and those in data.

# %%
ko4=read.csv('../kegg_names/ko4_ls.csv')
ko8=read.csv('../kegg_names/ko8_ls.csv')
ko6=read.csv('../kegg_names/ko6_ls.csv')
ko13=read.csv('../kegg_names/ko13_ls.csv')
head(ko13)
# Out:
#   orfs                                              ko_iteration ko_id
# 1 NODE_10000_length_2085_cov_180.263917_g1941_i2.p2 ko:_1        K19364
# 2 NODE_10000_length_2085_cov_180.263917_g1941_i2.p3 ko:_1        K19364
# 3 NODE_10002_length_2085_cov_50.039761_g2374_i1.p2  ko:_1        K01142
# 4 NODE_10002_length_2085_cov_50.039761_g2374_i1.p2  ko:_2        K01930
# 5 NODE_10002_length_2085_cov_50.039761_g2374_i1.p2  ko:_3        K10771
# 6 NODE_10005_length_2085_cov_13.522366_g594_i1.p1   ko:_1        K00850

# %%
a=unique(ko4$ko_id)
a=a[a%in%heat.path$ko_id]

b=unique(ko8$ko_id)
b=b[b%in%heat.path$ko_id]

c=unique(ko6$ko_id)
c=c[c%in%heat.path$ko_id]

d=unique(ko13$ko_id)
d=d[d%in%heat.path$ko_id]


length(b)
length(c)
length(d)
length(a)
x=union(a,b)
y=union(c,d)
z=union(x,y)

length(x)
length(y)
length(z)
st=heat.path[(heat.path$ko_id)%in%z,]
nrow(st)
length(unique(heat.path$ko_id))
# Out:
# [1] 87
# [1] 97
# [1] 93
# [1] 91
# [1] 96
# [1] 99
# [1] 113
# [1] 113
# [1] 113

# %%
mod.path=function(df,ko){
    inner_join(x = ko, y=df,by = 'ko_id', relationship='many-to-many')
    }

path4=mod.path(sub_path, ko4)
path8=mod.path(sub_path, ko8)
path6=mod.path(sub_path, ko6)
path13=mod.path(sub_path, ko13)

write.csv(path4,'../kegg_names/path4.csv',row.names=FALSE)
write.csv(path8,'../kegg_names/path8.csv',row.names=FALSE)
write.csv(path6,'../kegg_names/path6.csv',row.names=FALSE)
write.csv(path13,'../kegg_names/path13.csv',row.names=FALSE)

sub_path=bind_rows(path4,path8,path6,path13)
sub_path=sub_path[,-c(1:2)] %>% distinct()

write.csv(all.path,'../kegg_names/all.path.csv', row.names=F)

# %%
mod4=mod.path(sub_mod_all, ko4)
mod8=mod.path(sub_mod_all, ko8)
mod6=mod.path(sub_mod_all, ko6)
mod13=mod.path(sub_mod_all, ko13)

write.csv(mod4,'../kegg_names/mod4.csv',row.names=FALSE)
write.csv(mod8,'../kegg_names/mod8.csv',row.names=FALSE)
write.csv(mod6,'../kegg_names/mod6.csv',row.names=FALSE)
write.csv(mod13,'../kegg_names/mod13.csv',row.names=FALSE)

#now rewriting sub_cat table so only genes found in my organisms show up
all.mod=bind_rows(mod4,mod8,mod6,mod13)
all.mod=all.mod[,-c(1:2)] %>% distinct()

write.csv(all.mod,'../kegg_names/all.mod.csv', row.names=F)

# %% [markdown]
# ----
# # Old way of extracting pathways of interest

# %%
## List of pathways of interest with ko-id's associated. 
## find orfs and counts within pathways and plot on heatmap
## add name of pathway in df by joinging pathways dataframes

select.paths <- data.frame(Name=c('Nitrogen Metabolism', 
                                'Photosynthesis', 
                                'Oxidative Phosphorylation', 
                                'Photosynthesis-antenna Proteins', 
                                'Carbon Fixation',
                               'Methan Metabolism', 
                                'Sulfur Metabolism',
                                'Citrate Cycle', 
                                'Glycolysis', 
                                'ABC Transport', 
                                'Phosphotransferase System'),
                      path_id=c('map00910', 'map00195', 'map00190','map00196', 'map00710',
                              'map00680', 'map00920', 'map00020', 'map00010', 'map02010', 'map02060'))
#keggLink('ko', 'map00910')

code <- list(select.paths$path_id)
head(code)
for (i in code){
   #print(keggList(i))
    pathways <- as.matrix(keggLink('ko', i))
}
pathways <- data.frame('ko_id'=pathways) %>% rownames_to_column('path_id')  
pathways$path_id <- gsub('path.', '', pathways$path_id)
pathways$ko_id <- gsub('ko:','', pathways$ko_id)
pathways$path_id <- str_remove(pathways$path_id, '\\.[[:digit:]]+')
pathways <- pathways %>% group_by(path_id)

select.pathways <- left_join(pathways, select.paths, by='path_id')
write.csv(select.pathways, '../kegg_names/select.pathways.csv', row.names=FALSE)
# Out:
# [[1]]
#  [1] "map00910" "map00195" "map00190" "map00196" "map00710" "map00680"
#  [7] "map00920" "map00020" "map00010" "map02010" "map02060"
